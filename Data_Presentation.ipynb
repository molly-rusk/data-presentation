# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Absenteeism_at_work.tsv", sep='\t')
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
df = df.drop(['ID', 'Service time', 'Son'], axis=1)

# %%
df.columns
# Out:
# Index(['Reason for absence', 'Month of absence', 'Day of the week', 'Seasons',
#        'Transportation expense', 'Distance from Residence to Work', 'Age',
#        'Work load Average/day ', 'Hit target', 'Disciplinary failure',
#        'Education', 'Social drinker', 'Social smoker', 'Pet', 'Weight',
#        'Height', 'Body mass index', 'Absenteeism time in hours'],
#       dtype='object')

# %%
df
# Out:
#      Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                    26                 7                3        1
# 1                     0                 7                3        1
# 2                    23                 7                4        1
# 3                     7                 7                5        1
# 4                    23                 7                5        1
# ..                  ...               ...              ...      ...
# 735                  14                 7                3        1
# 736                  11                 7                3        1
# 737                   0                 0                3        1
# 738                   0                 0                4        2
# 739                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Age  \
# 0                       289                               36   33
# ...

# %%
df.describe()
# Out:
#        Reason for absence  Month of absence  Day of the week     Seasons  \
# count          740.000000        740.000000       740.000000  740.000000
# mean            19.216216          6.324324         3.914865    2.544595
# std              8.433406          3.436287         1.421675    1.111831
# min              0.000000          0.000000         2.000000    1.000000
# 25%             13.000000          3.000000         3.000000    2.000000
# 50%             23.000000          6.000000         4.000000    3.000000
# 75%             26.000000          9.000000         5.000000    4.000000
# max             28.000000         12.000000         6.000000    4.000000
#
#        Transportation expense  Distance from Residence to Work         Age  \
# count              740.000000                       740.000000  740.000000
# mean               221.329730                        29.631081   36.450000
# std                 66.952223                        14.836788    6.478772
# ...

# %%
df['Reason for absence'].value_counts()
# Out:
# 23    149
# 28    112
# 27     69
# 13     55
# 0      43
# 19     40
# 22     38
# 26     33
# 25     31
# 11     26
# 10     25
# 18     21
# 14     19
# 1      16
# 7      15
# 6       8
# 12      8
# 21      6
# 8       6
# 9       4
# 5       3
# 16      3
# 24      3
# 15      2
# 4       2
# 3       1
# 2       1
# 17      1
# Name: Reason for absence, dtype: int64

# %%
top5 = df['Reason for absence'].value_counts().head(5)
top5
# Out:
# 23    149
# 28    112
# 27     69
# 13     55
# 0      43
# Name: Reason for absence, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 28    117
# 38    113
# 37     78
# 40     58
# 33     51
# 36     50
# 30     46
# 50     37
# 41     34
# 34     29
# 43     24
# 47     24
# 31     22
# 32     13
# 58      8
# 39      8
# 29      7
# 27      7
# 48      6
# 49      5
# 46      2
# 53      1
# Name: Age, dtype: int64

# %%
df[['Age', 'Absenteeism time in hours']].sort_values('Absenteeism time in hours', ascending=False).head(10)
# Out:
#      Age  Absenteeism time in hours
# 323   34                        120
# 729   58                        120
# 420   50                        120
# 471   28                        112
# 622   58                        112
# 652   33                        104
# 734   31                         80
# 569   34                         80
# 231   50                         80
# 682   43                         64

# %%
age28 = df[df['Age'] == 28]
age28
# Out:
#      Reason for absence  Month of absence  Day of the week  Seasons  \
# 6                    22                 7                6        1
# 20                   10                 8                4        1
# 22                   13                 8                2        1
# 25                   25                 8                2        1
# 35                   23                 8                2        1
# ..                  ...               ...              ...      ...
# 697                  10                 5                5        3
# 701                   7                 5                2        3
# 705                  11                 5                2        3
# 732                  22                 7                4        1
# 733                  22                 7                4        1
#
#      Transportation expense  Distance from Residence to Work  Age  \
# 6                       361                               52   28
# ...

# %%
df['Age'].value_counts().sort_values(ascending=False)
# Out:
# 28    117
# 38    113
# 37     78
# 40     58
# 33     51
# 36     50
# 30     46
# 50     37
# 41     34
# 34     29
# 47     24
# 43     24
# 31     22
# 32     13
# 58      8
# 39      8
# 29      7
# 27      7
# 48      6
# 49      5
# 46      2
# 53      1
# Name: Age, dtype: int64

# %%
df.groupby('Age')['Absenteeism time in hours'].sum().sort_values(ascending=False)
# Out:
# Age
# 28    651
# 33    538
# 38    482
# 34    476
# 37    465
# 40    379
# 36    346
# 50    327
# 41    275
# 58    262
# 30    253
# 31    217
# 43    187
# 47     73
# 32     48
# 29     31
# 39     30
# 27     27
# 48     25
# 49     16
# 46     16
# 53      0
# Name: Absenteeism time in hours, dtype: int64

# %%
absencesperage = df.groupby('Age')['Absenteeism time in hours'].sum()
absencesperage
# Out:
# Age
# 27     27
# 28    651
# 29     31
# 30    253
# 31    217
# 32     48
# 33    538
# 34    476
# 36    346
# 37    465
# 38    482
# 39     30
# 40    379
# 41    275
# 43    187
# 46     16
# 47     73
# 48     25
# 49     16
# 50    327
# 53      0
# 58    262
# Name: Absenteeism time in hours, dtype: int64

# %%
fig, ax = plt.subplots()
absencesperage.plot.bar(ax=ax, stacked=True)
plt.ylabel('Hours')
plt.title('Total hours of absence per age')
plt.xticks(rotation=60)
fig.tight_layout()

# %%
ages = df['Age'].value_counts()
ages
# Out:
# 28    117
# 38    113
# 37     78
# 40     58
# 33     51
# 36     50
# 30     46
# 50     37
# 41     34
# 34     29
# 43     24
# 47     24
# 31     22
# 32     13
# 58      8
# 39      8
# 29      7
# 27      7
# 48      6
# 49      5
# 46      2
# 53      1
# Name: Age, dtype: int64

# %%
ages.plot.bar()
plt.title('Counts of ages in the workplace')
plt.ylabel('Count')
plt.xlabel('Age')
plt.show()

# %%
dayabsent = df['Day of the week'].value_counts().head()
dayabsent
# Out:
# 2    161
# 4    156
# 3    154
# 6    144
# 5    125
# Name: Day of the week, dtype: int64

# %%
fig, ax = plt.subplots()
dayabsent.plot.bar()
plt.xlabel('Day of the week')
plt.ylabel('Total days absent')
plt.title('Days of absence')
plt.xticks(rotation=0)
fig.tight_layout()

# %%
monthofabsence = df['Month of absence'].value_counts()
monthofabsence
# Out:
# 3     87
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# 0      3
# Name: Month of absence, dtype: int64

# %%
monthofabsence.plot.bar()
plt.title('Number of absences per month')
plt.xticks(rotation=0)
plt.xlabel('Month')
plt.ylabel('Absences')
plt.show()
